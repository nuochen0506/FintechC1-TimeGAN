# %% [markdown]
# ## Synthetic Daily Data

# %%
import pandas as pd
import numpy as np

daily = pd.read_csv('Daily_data.csv')
daily = daily.rename(columns={'AdjClose': 'real_daily'})
daily
# Out:
#           Date  real_daily  synthetic_daily
# 0    2021/2/23  245.529999       198.707945
# 1    2021/2/24  248.449997       205.128890
# 2    2021/2/25  243.690002       205.484121
# 3    2021/2/26  240.509995       202.371377
# 4     2021/3/1  249.210007       203.311994
# ..         ...         ...              ...
# 247  2022/2/14  314.279999       202.220479
# 248  2022/2/15  316.200012       202.392183
# 249  2022/2/16  315.649994       203.806622
# 250  2022/2/17  313.549988       203.038741
# 251  2022/2/18  314.799988       202.582929
#
# [252 rows x 3 columns]

# %% [markdown]
# ### Raw Price Comparison

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style = 'white', palette = 'pastel')
fig, ax = plt.subplots(figsize=(8,6))
daily.plot(ax=ax, title='BRK-B',secondary_y='synthetic_daily', style=['-', '--'],lw=1)

# %%
idx = np.random.randint(252-48)

dataframe = pd.DataFrame({'Real': daily['real_daily'][idx:idx+48], 'Synthetic': daily['synthetic_daily'][idx:idx+48]})
dataframe.plot(figsize=(8,6),title='BRK-B',secondary_y='Synthetic', style=['-', '--'],lw=1)

# %%
idx = np.random.randint(252-48)

dataframe = pd.DataFrame({'Real': daily['real_daily'][idx:idx+48], 'Synthetic': daily['synthetic_daily'][idx:idx+48]})
dataframe.plot(figsize=(8,6),title='BRK-B',secondary_y='Synthetic', style=['-', '--'],lw=1)

# %% [markdown]
# ### Log Return Comparison

# %%
real_daily_return = np.log(daily['real_daily']/daily['real_daily'].shift())
synthetic_daily_return = np.log(daily['synthetic_daily']/daily['synthetic_daily'].shift())

# %%
sns.set_theme(style = 'white', palette = 'pastel')
fig, ax = plt.subplots(figsize=(8,6))
real_daily_return[1:].plot(ax=ax, label = 'Real Data')
synthetic_daily_return[1:].plot(ax=ax, label = 'Synthetic Data')
ax.set_xlabel('Log return')
ax.set_ylabel('Freq of log return')
ax.set_title('BRK-B Daily Real vs. Synthetic Data Volatility')
ax.legend(['Real Data','Synthetic Data'])
plt.show()

# %%
sns.set_theme(style = 'white', palette = 'pastel')
fig, ax = plt.subplots(figsize=(8,6))
synthetic_daily_return[-44:].plot(ax=ax, label = 'Synthetic Data')
real_daily_return[-44:].plot(ax=ax, label = 'Real Data')
ax.set_xlabel('Log return')
ax.set_ylabel('Freq of log return')
ax.set_title('BRK-B Daily Real vs. Synthetic Data Volatility')
ax.legend(['Synthetic Data','Real Data'])
plt.show()

# %% [markdown]
# ### Volatility Clustering

# %%
sns.set_theme(style = 'white', palette = 'pastel')
fig, ax = plt.subplots(figsize=(8,6))
real_daily_return[1:].hist(ax=ax, label = 'Real Data')
ax.set_xlabel('Log return')
ax.set_ylabel('Freq of log return')
ax.set_title('BRK-B Daily Real Data Volatility')
plt.grid(b=None)
plt.legend()
plt.show()

# %%
sns.set_theme(style = 'white', palette = 'pastel')
fig, ax = plt.subplots(figsize=(8,6))
real_daily_return[1:].hist(ax=ax, label = 'Real Data')
synthetic_daily_return[1:].hist(ax=ax, alpha=0.6, label = 'Synthetic Data')
ax.set_xlabel('Log return')
ax.set_ylabel('Freq of log return')
ax.set_title('BRK-B Daily Real vs. Synthetic Data Volatility')
plt.grid(b=None)
plt.legend()
plt.show()

# %% [markdown]
# ## Synthetic High Frequency (30 minutes) Data

# %%
highfreq = pd.read_csv('30mins_data.csv')
highfreq = highfreq.rename(columns={'ThirtyMin': 'real_30min'})
highfreq
# Out:
#                 Date  real_30min  synthetic_30min
# 0    2022/1/26 13:30    312.3200       288.421262
# 1    2022/1/26 14:00    312.7700       284.908279
# 2    2022/1/26 14:30    310.4303       282.134309
# 3    2022/1/26 15:00    307.7400       282.106678
# 4    2022/1/26 15:30    309.1600       282.170420
# ..               ...         ...              ...
# 468  2022/3/18 13:30    341.1250       285.665441
# 469  2022/3/18 14:00    341.7900       285.616375
# 470  2022/3/18 14:30    341.6034       285.615245
# 471  2022/3/18 15:00    342.8200       285.521828
# 472  2022/3/18 15:30    342.5900       285.484554
#
# [473 rows x 3 columns]

# %% [markdown]
# ### Raw Price Comparison

# %%
sns.set_theme(style = 'white', palette = 'pastel')
fig, ax = plt.subplots(figsize=(8,6))
highfreq.plot(ax=ax, title='BRK-B',secondary_y='synthetic_30min', style=['-', '--'],lw=1)

# %%
idx = np.random.randint(473-48)

dataframe = pd.DataFrame({'Real': highfreq['real_30min'][idx:idx+48], 'Synthetic': highfreq['synthetic_30min'][idx:idx+48]})
dataframe.plot(figsize=(8,6),title='BRK-B',secondary_y='Synthetic', style=['-', '--'],lw=1)

# %%
idx = np.random.randint(473-48)

dataframe = pd.DataFrame({'Real': highfreq['real_30min'][idx:idx+48], 'Synthetic': highfreq['synthetic_30min'][idx:idx+48]})
dataframe.plot(figsize=(8,6),title='BRK-B',secondary_y='Synthetic', style=['-', '--'],lw=1)

# %% [markdown]
# ### Log Return Comparison

# %%
real_30min_return = np.log(highfreq['real_30min']/highfreq['real_30min'].shift())
synthetic_30min_return = np.log(highfreq['synthetic_30min']/highfreq['synthetic_30min'].shift())

# %%
sns.set_theme(style = 'white', palette = 'pastel')
fig, ax = plt.subplots(figsize=(8,6))
real_30min_return[1:].plot(ax=ax, label = 'Real Data')
synthetic_30min_return[1:].plot(ax=ax, label = 'Synthetic Data')
ax.set_xlabel('Log return')
ax.set_ylabel('Freq of log return')
ax.set_title('BRK-B 30Min Real vs. Synthetic Data Volatility')
ax.legend(['Real Data','Synthetic Data'])
plt.show()

# %%
sns.set_theme(style = 'white', palette = 'pastel')
fig, ax = plt.subplots(figsize=(8,6))
synthetic_30min_return[-44:].plot(ax=ax, label = 'Synthetic Data')
real_30min_return[-44:].plot(ax=ax, label = 'Real Data')
ax.set_xlabel('Log return')
ax.set_ylabel('Freq of log return')
ax.set_title('BRK-B 30Min Real vs. Synthetic Data Volatility')
ax.legend(['Synthetic Data','Real Data'])
plt.show()

# %% [markdown]
# ### Volatility Clustering

# %%
sns.set_theme(style = 'white', palette = 'pastel')
fig, ax = plt.subplots(figsize=(8,6))
real_30min_return[1:].hist(ax=ax, label = 'Real Data')
ax.set_xlabel('Log return')
ax.set_ylabel('Freq of log return')
ax.set_title('BRK-B 3OMin Real Data Volatility')
plt.grid(b=None)
plt.legend()
plt.show()

# %%
sns.set_theme(style = 'white', palette = 'pastel')
fig, ax = plt.subplots(figsize=(8,6))
real_30min_return[1:].hist(ax=ax, label = 'Real Data')
synthetic_30min_return[1:].hist(ax=ax, alpha=0.6, label = 'Synthetic Data')
ax.set_xlabel('Log return')
ax.set_ylabel('Freq of log return')
ax.set_title('BRK-B 30Min Real vs. Synthetic Data Volatility')
plt.grid(b=None)
plt.legend()
plt.show()
