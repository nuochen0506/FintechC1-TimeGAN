# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("daily.csv")
# change the file name of the 30 minites data to see the acf plot on 30 minutes data
df['log return'] = np.log(df['AdjClose'][1:]) - np.log(df['AdjClose'][1:].iloc[0])

# %%
#sns.set_theme(style = 'white', palette = 'pastel')
#plt.figure(figsize = (8,6))

# %%
#daily[].autocorr(lag=1)

# %%
from statsmodels.graphics.tsaplots import plot_acf
fig, ax = plt.subplots(figsize=(8, 6))
plot_acf(daily['AdjClose'][1:], title = 'Real Data Autocorrelation', lags = 50, ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))
plot_acf(daily['synthetic_daily'][1:], title = 'Synthetic Data Autocorrelation', lags = 50,ax=ax)
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf
df['log return'] = np.log(df['AdjClose'][1:]) - np.log(df['AdjClose'][1:].iloc[0])
fig, ax = plt.subplots(figsize=(8, 6))
plot_acf(df['log return'], title = 'Real Data Autocorrelation', lags = 50, ax=ax)
plt.show()
